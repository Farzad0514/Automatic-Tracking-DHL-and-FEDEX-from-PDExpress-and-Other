# %%
import pandas as pd
import os

# %%
os.chdir('F:\\Miscellaneous drive\\waste\\kicxpert\\hafiz courier\\office\\FILES')

old= pd.read_csv('FARZAD_V1.csv')

# %%
old.shape
# Out:
# (757, 18)

# %%
old.head()
# Out:
#          DATE SERVICE           APX NO  DHL / FEDEX NO            SHIPPEER  \
# 0  18.11.2020     DHL  364084~28737130    5.022999e+09   DEURA ENTERPRISES
# 1  18.11.2020     DHL  345221~08150044    5.022999e+09  FALBRO ENTERPRISES
# 2  18.11.2020     DHL  345223~08150044    5.022999e+09  FALBRO ENTERPRISES
# 3  18.11.2020     DHL  341108~42372801    5.023000e+09      GLOBAL FASHION
# 4  18.11.2020     DHL  360251~79585571    5.023000e+09        GUJJAR IMPEX
#
#                     COUNTRY  PCS  WEIGHT  APX  DOX / WPX      CONSIGNEE NAME  \
# 0  UNITED STATES OF AMERICA  1.0    3.32   0.5       WPX       TERRELL WALLS
# 1  UNITED STATES OF AMERICA  2.0   46.86  20.0       WPX          RYAN CHANG
# 2  UNITED STATES OF AMERICA  2.0   45.94  20.0       WPX  RED LABEL CLOTHING
# 3  UNITED STATES OF AMERICA  2.0   30.46  20.0       WPX        JOSEPH BRADY
# 4          NETHERLANDS, THE  1.0    0.50   0.5       WPX      VALHALLAH MASK
#
# ...

# %%
uniqueId= old['DHL / FEDEX NO']

# %%
old.shape
# Out:
# (757, 18)

# %%
str(uniqueId[4])
# Out:
# '5022999811.0'

# %%
find == '5022999811'

str(find) in str(uniqueId[4])
# Out:
# True

# %%
for i in range(0, int(len(old))):
    if str(find) in str(uniqueId[i]):
        print('found')
    else: print('notfound')
# Out:
# notfound
# notfound
# notfound
# notfound
# found
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# notfound
# ...

# %% [raw]
# uniqueId[4].r

# %%
uniqueId[4] = 5022999811
# Out:
# <ipython-input-31-9563bc015b11>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uniqueId[4] = 5022999811
